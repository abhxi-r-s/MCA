# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn import metrics
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

iris = pd.read_csv("test1.csv")
print(iris.head())

X = iris[['sore_threat', 'fever', 'swollen_glands', 'congestion', 'headache']]
y = iris['diagnosis']  

fname = ['sore_threat', 'fever', 'swollen_glands', 'congestion', 'headache']
tname = ['Allergy', 'Cold', 'Strep_Throat']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier(criterion="entropy")
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(metrics.classification_report(y_test, y_pred))

newcase = [[0, 0, 1, 0, 0]]
y_new = clf.predict(newcase)
print(f"Prediction for new case: {y_new}")

plt.figure(figsize=(12,8))
tree.plot_tree(clf, fontsize=10, filled=True, rounded=True, class_names=tname, feature_names=fname)
plt.show()
# Out:
#    sore_threat  fever  swollen_glands  congestion  headache     diagnosis
# 0            1      1               1           0         1  Strep_Throat
# 1            0      1               0           1         1          Cold
# 2            0      0               0           1         0       Allergy
# 3            1      1               1           0         0  Strep_Throat
# 4            0      1               0           1         0          Cold
#               precision    recall  f1-score   support
#
#      Allergy       1.00      1.00      1.00         1
#         Cold       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
# Prediction for new case: ['Strep_Throat']
# ...

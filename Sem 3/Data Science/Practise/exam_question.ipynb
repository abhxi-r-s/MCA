# %% [markdown]
# Disease prediction system using a Decision Tree Classifier

# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")
print(df)
# Out:
#    sore_throat  headache  fever           disease
# 0            1         1      1               Flu
# 1            1         0      1       Common Cold
# 2            0         1      1          Migraine
# 3            1         1      0  Throat Infection
# 4            0         0      1           Typhoid
# 5            0         1      0            Stress
# 6            1         0      0           Allergy
# 7            0         0      0           Healthy

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
x=df[['sore_throat','headache','fever']]
y=df['disease']

# %%
clf=DecisionTreeClassifier(criterion='entropy',random_state=42)
clf.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
import matplotlib.pyplot as plt

plt.Figure(figsize=(5,5))
plot_tree(clf,filled=True)
plt.show()
